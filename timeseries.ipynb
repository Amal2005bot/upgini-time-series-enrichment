# %% [markdown]
# <a href="https://colab.research.google.com/github/Amal2005bot/upgini-time-series-enrichment/blob/main/timeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -Uq upgini catboost

# %%
from os.path import exists
import pandas as pd

df_path="train.csv.zip" if exists("train.csv.zip") else "https://github.com/upgini/upgini/raw/main/notebooks/train.csv.zip"
df = pd.read_csv(df_path)
df = df.sample(n=19_000, random_state=0)
df["store"]=df["store"].astype(str)
df["item"]=df["item"].astype(str)

df["date"]= pd.to_datetime(df["date"])
df.sort_values("date", inplace=True)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#         date store item  sales
# 0 2013-01-01     7    5      5
# 1 2013-01-01     4    9     19
# 2 2013-01-01     1   33     37
# 3 2013-01-01     3   41     14
# 4 2013-01-01     5   24     26

# %%
train = df[df["date"] < "2017-01-01"]
test = df[df["date"]>= "2017-01-01"]

# %%
train_features = train.drop(columns=["sales"])
train_target=train["sales"]
test_features = test.drop(columns=["sales"])
test_target = test["sales"]

# %%
from upgini import FeaturesEnricher, SearchKey
from upgini.metadata import CVType

enricher = FeaturesEnricher(
    search_keys={
        "date": SearchKey.DATE,
    },
    cv=CVType.time_series,
)

enricher.fit(
    train_features,
    train_target,
    eval_set=[(test_features, test_target)]
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2755183691.py in <cell line: 0>()
#       2 from upgini.metadata import CVType
#       3
# ----> 4 enricher = FeaturesEnricher(
#       5     search_keys={
#       6         "date": SearchKey.DATE,
#
# /usr/local/lib/python3.12/dist-packages/upgini/features_enricher.py in __init__(self, search_keys, country_code, model_task_type, api_key, endpoint, search_id, shared_datasets, runtime_parameters, date_format, random_state, cv, loss, autodetect_search_keys, generate_features, text_features, columns_for_online_api, round_embeddings, logs_enabled, raise_validation_error, exclude_columns, baseline_score_column, client_ip, client_visitorid, custom_bundle_config, add_date_if_missing, disable_force_downsampling, id_columns, generate_search_key_features, sample_config, print_trace_id, print_loaded_report, **kwargs)
#     250         if self._api_key is not None and not isinstance(self._api_key, str):
#     251             raise ValidationError(f"api_key should be `string`, but passed: `{api_key}`")
# --> 252         self.rest_client = get_rest_client(endpoint, self._api_key, client_ip, client_visitorid)
#     253         self.client_ip = client_ip
#     254         self.client_visitorid = client_visitorid
#
# /usr/local/lib/python3.12/dist-packages/upgini/http.py in get_rest_client(backend_url, api_token, client_ip, client_visitorid)
#     970     token = resolve_api_token(api_token)
#     971
# --> 972     return _get_rest_client(url, token, client_ip, client_visitorid)
#     973
#     974
#
# /usr/local/lib/python3.12/dist-packages/upgini/http.py in _get_rest_client(backend_url, api_token, client_ip, client_visitorid)
#     981     backend_url: str, api_token: str, client_ip: Optional[str] = None, client_visitorid: Optional[str] = None
#     982 ) -> _RestClient:
# --> 983     return _RestClient(backend_url, api_token, client_ip, client_visitorid)
#     984
#     985
#
# /usr/local/lib/python3.12/dist-packages/upgini/http.py in __init__(self, service_endpoint, refresh_token, client_ip, client_visitorid)
#     317         self.client_ip = client_ip
#     318         self.client_visitorid = client_visitorid
# --> 319         self._access_token = self._refresh_access_token()
#     320         # self._access_token: Optional[str] = None  # self._refresh_access_token()
#     321         self.last_refresh_time = time.time()
#
# /usr/local/lib/python3.12/dist-packages/upgini/http.py in _refresh_access_token(self, retry_attempts_rest)
#     324         api_path = self.REFRESH_TOKEN_URI_FMT
#     325         try:
# --> 326             response = requests.post(
#     327                 url=urljoin(self._service_endpoint, api_path),
#     328                 json={"refreshToken": self._refresh_token},
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     462             # Trigger any extra validation we need to do.
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#     466                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1091         # Force connect early to allow us to validate the connection.
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#    1095         # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in connect(self)
#     788             server_hostname_rm_dot = server_hostname.rstrip(".")
#     789
# --> 790             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791                 sock=sock,
#     792                 cert_reqs=self.cert_reqs,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     967             server_hostname = normalized
#     968
# --> 969     ssl_sock = ssl_wrap_socket(
#     970         sock=sock,
#     971         keyfile=key_file,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     478     context.set_alpn_protocols(ALPN_PROTOCOLS)
#     479
# --> 480     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     481     return ssl_sock
#     482
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     522         return SSLTransport(sock, ssl_context, server_hostname)
#     523
# --> 524     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.12/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     453         # SSLSocket class handles server_hostname encoding before it calls
#     454         # ctx._wrap_socket()
# --> 455         return self.sslsocket_class._create(
#     456             sock=sock,
#     457             server_side=server_side,
#
# /usr/lib/python3.12/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         # non-blocking
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042         except:
#    1043             try:
#
# /usr/lib/python3.12/ssl.py in do_handshake(self, block)
#    1317             if timeout == 0.0 and block:
#    1318                 self.settimeout(None)
# -> 1319             self._sslobj.do_handshake()
#    1320         finally:
#    1321             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
from catboost import CatBoostRegressor
from catboost.utils import eval_metric
model = CatBoostRegressor(verbose=False, allow_writing_files=False, random_state=0)
enricher.calculate_metrics(
    train_features, train_target,
    eval_set =[(test_features, test_target)],
    estimator = model,
    scoring= "mean_absolute_percentage_error"
)

# %%
enriched_train_features =enricher.transform(train_features, keep_input=True)
enriched_test_features =enricher.transform(test_features, keep_input=True)
enriched_train_features.head()

# %%
model.fit(train_features, train_target)
preds = model.predict(test_features)
eval_metric(test_target.values, preds, "SMAPE")

# %%
model.fit(enriched_train_features, train_target)
enriched_preds = model.predict(enriched_test_features)
eval_metric(test_target.values, enriched_preds, "SMAPE")
